# %%
events.event_name.value_counts()
# Out:
# event_name
# view_heatmap    299
# search_role     207
# login           161
# apply_filter    143
# view_company    100
# signup           53
# logout           37
# Name: count, dtype: int64

# %%
target_event = "search_role"

event_actions = events[events['event_name'] == target_event]

conversion_rates = (
    event_actions.groupby("group")['user_id'].nunique() /
    events.groupby("group")['user_id'].nunique()
).fillna(0)

print(conversion_rates)
# Out:
# group
# A    0.464865
# B    0.407609
# Name: user_id, dtype: float64
